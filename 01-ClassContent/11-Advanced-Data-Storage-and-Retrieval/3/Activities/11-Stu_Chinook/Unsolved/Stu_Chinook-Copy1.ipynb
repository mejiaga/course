# %%
# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
# YOUR CODE HERE
import datetime as dt
import numpy as np
import pandas as pd

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from flask import Flask, jsonify
import func, inspect
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-185870278922> in <module>()
#      11
#      12 from flask import Flask, jsonify
# ---> 13 import func, inspect
#
# ModuleNotFoundError: No module named 'func'

# %%
# Create an engine for the chinook.sqlite database
# YOUR CODE HERE
engine = create_engine("sqlite:///chinook.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table
# how to get columns for a class ***
invoices = Base.classes.invoices
inspector = inspect(engine)
inspector.get_columns("invoices")


# Create our session (link) from Python to the DB
session = Session(engine)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     209         try:
# --> 210             return self._data[key]
#     211         except KeyError:
#
# KeyError: 'passenger'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e33c0955dcf8> in <module>()
#       7
#       8 # Save reference to the table
# ----> 9 Passenger = Base.classes.passenger
#      10
#      11 # Create our session (link) from Python to the DB
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\util\_collections.py in __getattr__(self, key)
#     210             return self._data[key]
#     211         except KeyError:
# --> 212             raise AttributeError(key)
#     213
#     214     def __contains__(self, key):
#
# AttributeError: passenger

# %%
# Reflect Database into ORM classes
# YOUR CODE HERE

# %%
# Save a reference to the invoices table as `Invoices`
# YOUR CODE HERE

# %%
# Create a database session object
# YOUR CODE HERE
session = Session(engine)

# %%
# List all of the countries found in the invoices table
# YOUR CODE HERE

# %%
# Design a query that lists the invoices totals for each billing country 
# and sort the output in descending order.
# YOUR CODE HERE

# %%
# Save a reference to the invoice_items table as `Items`
# YOUR CODE HERE

# %%
# List all of the Billing Postal Codes for the USA.
# YOUR CODE HERE

# %%
# Calculate the Item Totals (sum(UnitPrice * Quantity)) for the USA
# YOUR CODE HERE

# %%
# Calculate the Item Totals `sum(UnitPrice * Quantity)` for each Billing Postal Code in the USA
# Sort the results in descending order by Total
# YOUR CODE HERE
