# %%
# Dependencies and boilerplate
from sqlalchemy import Column, Float, Integer, String
from sqlalchemy.ext.declarative import declarative_base
# from sqlalchemy import session

Base = declarative_base()

# %%
from sqlalchemy import create_engine

# %%
# Define a Prescription class
# YOUR CODE HERE
class Prescription(Base):
        __tablename__ = "priscription"
        priscription_id = Column(String, primary_key=True)
        name = Column(String)
        strength = Column(Integer)
        doses_per_administration = Column(Integer)
      route_of_administration = Column(String)
      administrations_per_day = Column(String)
      total_quantity_to_dispense = Column(Integer)
      refill_limit = Column(Integer)
      refill_frequency = Column(Integer)
# Out:
#   File "<ipython-input-9-4646e00373c3>", line 6
#     priscription_id = Column(String, primary_key=True)
#     ^
# IndentationError: unexpected indent

# %%
# Create Database Connection
engine = create_engine('sqlite:///../Resources/prescriptions.sqlite')
Base.metadata.create_all(engine)
session = Session(bind=engine)

# %%
# Use a Session to test the Prescription class
# YOUR CODE HERE

# %%
# Create and add two new scripts `haloperidol` and `theriac`
# YOUR CODE HERE
haloperidol = Prescription(
name = haloperidol,
strength = 10,
doses_per_administration = 2
#       route_of_administration = Column(String)
#       administrations_per_day = Column(String)
#       total_quantity_to_dispense = Column(Integer)
#       refill_limit = Column(Integer)
#       refill_frequency 

)

# %%
# Add and commit the two new scripts
# YOUR CODE HERE
session.add_all([theriac,heloperidol])
session.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-af23e36058d0> in <module>()
#       1 # Add and commit the two new scripts
#       2 # YOUR CODE HERE
# ----> 3 session.add_all([theriac,heloperidol])
#       4 session.commit()
#
# NameError: name 'session' is not defined

# %%
# Verify commit
# YOUR CODE HERE

print(haloperidol_record.name)
print("-" * 12)
print(theriac_record.name)
