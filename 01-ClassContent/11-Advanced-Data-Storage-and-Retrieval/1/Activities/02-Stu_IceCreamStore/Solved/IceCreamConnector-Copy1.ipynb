# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()
import pprint

# %%
# Copied from lesson 1
# # Create Engine and Pass in MySQL Connection
# engine = create_engine("mysql://k5xunpkmojyzse51:ifagg1gp7e2xyapi@ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/tq6h098h0ym00zp6")

# # Query All Records in the the Database
# data = engine.execute("SELECT * FROM Census_Data")

# for record in data:
#     pprint.pprint(record)

# %%
# Create Engine and Pass in MySQL Connection

# <dialect> ://<username>:<password>@Host:port/databasename
# engine = create_engine("mysql://johnD:pwd123@myhost:3233/sportdb)
engine = create_engine(f"mysql://Riicha:juhipolkA#1122@Rutgers_Bootcamp:3306/birdsong_db")

# engine = create_engine("mysql://root@localhost/icecream_db")
# engine = create_engine("mysql://root:1234@localhost:3306/icecream_db")
# engine = create_engine("mysql://test:1234@localhost:3306/birdsong_db")
# engine = create_engine("mysql://root:test:1234@127.0.0.1:3306/birdsong_db")
# engine = create_engine("mysql://root:test:1234@Rutgers_Bootcamp/birdsong_db")
# engine = create_engine("mysql://root:test:123@Rutgers_Bootcamp/birdsong_db")
# engine = create_engine("mysql://localhost:root:test:@127.0.0.1/birdsong_db")
# engine = create_engine("mysql://test:1234@localhost:3306/birdsong_db")
# engine = create_engine("mysql://u:p@host/db", pool_size=10, max_overflow=20)
# engine = create_engine("mysql://root:test:@127.0.0.1/birdsong_db")
# engine = create_engine("mysql://test:123:@127.0.0.1:3306/birdsong_db")
# engine = create_engine('mysql://scott:tiger@localhost/foo')
# conn = connect.engine()
# engine = create_engine("mysql+pymysql://test:123@localhost/birdsong_db")

# %%
# Query All Records in the the Database
data = engine.execute("SELECT * FROM birdsong.genus")

for record in data:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     581                                 (self.host, self.port), self.connect_timeout,
# --> 582                                 **kwargs)
#     583                             break
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\socket.py in create_connection(address, timeout, source_address)
#     703     err = None
# --> 704     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     705         af, socktype, proto, canonname, sa = res
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
# copied
# Query All Records in the the Database
data = engine.execute("SELECT * FROM Census_Data")

for record in data:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
# ...

# %%
# Query All Records in the the Database
# data = engine.execute("SELECT * FROM icecreamstore")
data = engine.execute("SELECT * FROM genus")  
                      # birdsong.genus")
for record in data:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
# ...

# %%
# Query Single Record in the the Database
data = engine.execute("SELECT * FROM icecreamstore WHERE Price>=1.25;")
for record in data:
    print(record)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#
# ~\AppData\Local\conda\conda\envs\pythonData\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
# ...
