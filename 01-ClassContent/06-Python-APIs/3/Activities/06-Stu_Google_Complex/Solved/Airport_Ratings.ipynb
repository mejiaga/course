# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey

# %%
# Import cities file as DataFrame
cities_pd = pd.read_csv("../Resources/cities.csv")
cities_pd.head()
# Out:
#             City         State
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
# Note that we used "" to specify initial entry.
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Airport Name"] = ""
cities_pd["Airport Address"] = ""
cities_pd["Airport Rating"] = ""
cities_pd.head()
# Out:
#             City         State Lat Lng Airport Name Airport Address  \
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_pd.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    city = row['City']
    state = row['State']

    # update address key value
    params['address'] = f"{city},{state}"

    # make request, print url
    cities_lat_lng = requests.get(base_url, params=params)
    print(cities_lat_lng.url)
    # convert to json
    cities_lat_lng = cities_lat_lng.json()

    cities_pd.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
    cities_pd.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]

# Visualize to confirm lat lng appear
cities_pd.head()
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=New+York+City%2CNew+York
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Los+Angeles%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Chicago%2CIllinois
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Houston%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Philadelphia%2CPennsylvania
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Phoenix%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=San+Antonio%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=San+Diego%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Dallas%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=San+Jose%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Austin%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Jacksonville%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=San+Francisco%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Indianapolis%2CIndiana
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Columbus%2COhio
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Fort+Worth%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Charlotte%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Seattle%2CWashington
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Denver%2CColorado
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=El+Paso%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Detroit%2CMichigan
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Washington%2CDistrict+of+Columbia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Boston%2CMassachusetts
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Memphis%2CTennessee
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Nashville%2CTennessee
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Portland%2COregon
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Oklahoma+City%2COklahoma
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Las+Vegas%2CNevada
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Baltimore%2CMaryland
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Louisville%2CKentucky
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Milwaukee%2CWisconsin
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Albuquerque%2CNew+Mexico
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Tucson%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Fresno%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Sacramento%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Kansas+City%2CMissouri
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Long+Beach%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Mesa%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Atlanta%2CGeorgia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Colorado+Springs%2CColorado
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Virginia+Beach%2CVirginia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Raleigh%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Omaha%2CNebraska
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Miami%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Oakland%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Minneapolis%2CMinnesota
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Tulsa%2COklahoma
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Wichita%2CKansas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=New+Orleans%2CLouisiana
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Arlington%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Cleveland%2COhio
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Bakersfield%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Tampa%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Aurora%2CColorado
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Honolulu%2CHawai%27i
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Anaheim%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Santa+Ana%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Corpus+Christi%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Riverside%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=St.+Louis%2CMissouri
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Lexington%2CKentucky
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Stockton%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Pittsburgh%2CPennsylvania
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Saint+Paul%2CMinnesota
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Anchorage%2CAlaska
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Cincinnati%2COhio
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Henderson%2CNevada
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Greensboro%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Plano%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Newark%2CNew+Jersey
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Toledo%2COhio
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Lincoln%2CNebraska
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Orlando%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Chula+Vista%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Jersey+City%2CNew+Jersey
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Chandler%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Fort+Wayne%2CIndiana
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Buffalo%2CNew+York
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Durham%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=St.+Petersburg%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Irvine%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Laredo%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Lubbock%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Madison%2CWisconsin
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Gilbert%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Norfolk%2CVirginia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Reno%2CNevada
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Winston-Salem%2CNorth+Carolina
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Glendale%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Hialeah%2CFlorida
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Garland%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Scottsdale%2CArizona
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Irving%2CTexas
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Chesapeake%2CVirginia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=North+Las+Vegas%2CNevada
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Fremont%2CCalifornia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Baton+Rouge%2CLouisiana
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Richmond%2CVirginia
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=Boise%2CIdaho
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&address=San+Bernardino%2CCalifornia
#             City         State      Lat      Lng Airport Name Airport Address  \
# 0  New York City      New York  40.7128  -74.006
# 1    Los Angeles    California  34.0522 -118.244
# 2        Chicago      Illinois  41.8781 -87.6298
# 3        Houston         Texas  29.7604 -95.3698
# 4   Philadelphia  Pennsylvania  39.9526 -75.1652
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# params dictionary to update each iteration
params = {
    "radius": 50000,
    "types": "airport",
    "keyword": "international airport",
    "key": gkey
}

# Use the lat/lng we recovered to identify airports
for index, row in cities_pd.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    print(name_address.url)

    # convert to json
    name_address = name_address.json()
    # print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        cities_pd.loc[index, "Airport Name"] = name_address["results"][0]["name"]
        cities_pd.loc[index, "Airport Address"] = name_address["results"][0]["vicinity"]
        cities_pd.loc[index, "Airport Rating"] = name_address["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=40.7127753%2C-74.0059728
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=34.0522342%2C-118.2436849
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=41.8781136%2C-87.6297982
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=29.7604267%2C-95.3698028
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=39.9525839%2C-75.1652215
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.4483771%2C-112.0740373
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=29.4241219%2C-98.49362819999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=32.715738%2C-117.1610838
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=32.7766642%2C-96.79698789999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=37.3382082%2C-121.8863286
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=30.267153%2C-97.7430608
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=30.3321838%2C-81.65565099999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=37.7749295%2C-122.4194155
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=39.768403%2C-86.158068
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=39.9611755%2C-82.99879419999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=32.7554883%2C-97.3307658
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=35.2270869%2C-80.8431267
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=47.6062095%2C-122.3320708
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=39.7392358%2C-104.990251
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=31.7618778%2C-106.4850217
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=42.331427%2C-83.0457538
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=38.9071923%2C-77.0368707
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=42.3600825%2C-71.0588801
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=35.1495343%2C-90.0489801
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.1626638%2C-86.7816016
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=45.5230622%2C-122.6764815
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=35.4675602%2C-97.5164276
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.1699412%2C-115.1398296
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=39.2903848%2C-76.6121893
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=38.2526647%2C-85.7584557
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=43.0389025%2C-87.9064736
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=35.0843859%2C-106.650422
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=32.2226066%2C-110.9747108
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.7377981%2C-119.7871247
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=38.5815719%2C-121.4943996
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=39.0997265%2C-94.5785667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.7700504%2C-118.1937395
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.4151843%2C-111.8314724
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.7489954%2C-84.3879824
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=38.8338816%2C-104.8213634
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.8529263%2C-75.97798499999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=35.7795897%2C-78.6381787
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=41.2565369%2C-95.9345034
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=25.7616798%2C-80.1917902
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=37.8043637%2C-122.2711137
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=44.977753%2C-93.2650108
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.1539816%2C-95.99277500000001
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=37.68717609999999%2C-97.33005299999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=29.95106579999999%2C-90.0715323
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=32.735687%2C-97.10806559999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=41.49932%2C-81.6943605
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=35.3732921%2C-119.0187125
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=27.950575%2C-82.4571776
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=39.7294319%2C-104.8319195
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=21.3069444%2C-157.8583333
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.8365932%2C-117.9143012
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.7454725%2C-117.867653
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=27.8005828%2C-97.39638099999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.9806005%2C-117.3754942
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=38.6270025%2C-90.19940419999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=38.0405837%2C-84.5037164
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=37.9577016%2C-121.2907796
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=40.44062479999999%2C-79.9958864
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=44.9537029%2C-93.0899578
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=61.2180556%2C-149.9002778
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=39.1031182%2C-84.5120196
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.0395247%2C-114.9817213
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.0726354%2C-79.7919754
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.0198431%2C-96.6988856
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=40.735657%2C-74.1723667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=41.6528052%2C-83.5378674
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=40.813616%2C-96.7025955
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=28.5383355%2C-81.3792365
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=32.6400541%2C-117.0841955
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=40.72815749999999%2C-74.0776417
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.3061605%2C-111.8412502
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=41.079273%2C-85.1393513
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=42.88644679999999%2C-78.8783689
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=35.9940329%2C-78.898619
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=27.7676008%2C-82.64029149999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.6845673%2C-117.8265049
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=27.5305671%2C-99.48032409999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.5778631%2C-101.8551665
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=43.0730517%2C-89.4012302
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.3528264%2C-111.789027
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.8507689%2C-76.28587259999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=39.5296329%2C-119.8138027
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.09985959999999%2C-80.244216
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.5386523%2C-112.1859866
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=25.8575963%2C-80.2781057
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=32.912624%2C-96.63888329999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=33.4941704%2C-111.9260519
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=32.8140177%2C-96.9488945
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.7682088%2C-76.2874927
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=36.1988592%2C-115.1175013
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=37.5482697%2C-121.9885719
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=30.4514677%2C-91.18714659999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=37.5407246%2C-77.4360481
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=43.6187102%2C-116.2146068
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBArVIf1n768KazWANv4PYpZQAj8PQk53Y&location=34.1083449%2C-117.2897652

# %%
# Save Data to csv
cities_pd.to_csv("Airport_Output.csv")

# Visualize to confirm airport data appears
cities_pd.head(10)
# Out:
#             City         State      Lat      Lng  \
# 0  New York City      New York  40.7128  -74.006
# 1    Los Angeles    California  34.0522 -118.244
# 2        Chicago      Illinois  41.8781 -87.6298
# 3        Houston         Texas  29.7604 -95.3698
# 4   Philadelphia  Pennsylvania  39.9526 -75.1652
# 5        Phoenix       Arizona  33.4484 -112.074
# 6    San Antonio         Texas  29.4241 -98.4936
# 7      San Diego    California  32.7157 -117.161
# 8         Dallas         Texas  32.7767  -96.797
# 9       San Jose    California  37.3382 -121.886
#
#                                Airport Name                   Airport Address  \
# 0      Newark Liberty International Airport             3 Brewster Rd, Newark
# 1         Los Angeles International Airport          1 World Way, Los Angeles
# 2              O'Hare International Airport       10000 W O'Hare Ave, Chicago
# 3                  William P. Hobby Airport        7800 Airport Blvd, Houston
# 4        Philadelphia International Airport  8000 Essington Ave, Philadelphia
# 5  Phoenix Sky Harbor International Airport   3400 E Sky Harbor Blvd, Phoenix
# 6         San Antonio International Airport    9800 Airport Blvd, San Antonio
# 7           San Diego International Airport       3225 N Harbor Dr, San Diego
# 8   Dallas/Fort Worth International Airport     2400 Aviation Dr, DFW Airport
# 9       San Francisco International Airport                     San Francisco
#
#   Airport Rating
# 0            3.2
# 1            3.5
# 2            3.6
# 3              4
# 4            3.3
# 5            3.9
# 6              4
# 7            3.9
# 8            3.8
# 9            4.1
