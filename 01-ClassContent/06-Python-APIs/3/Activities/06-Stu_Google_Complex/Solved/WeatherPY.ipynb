# %% [markdown]
# # WeatherPY
#
# ## Analysis on WeatherPY
# ##### The plot on Latitude vs Temperature shows that the temperature is highest at the equator and lowest at the poles.
# ##### The humidity at the equator is in the range from 50%-100%. Howeever, the trends does not change based on the latitude.
# ##### There seems to be no co-relation of cloudliness with respect to the latitude.
# ##### The windspeed for most cities fall under 20mph and there seems to be no trend on the windspeed with respect to the latitude.

# %%
# Import the Dependencies
import pandas as pd
import numpy as np

import random
import requests as req

import matplotlib.pyplot as plt

import config as test
from citipy import citipy
import csv
# import openweathermapy as owm

#Gets the current date
import datetime
now = datetime.datetime.now()
now
# Out:
# datetime.datetime(2018, 6, 17, 9, 29, 5, 224153)

# %%
# File to Load 
world_cities = 'world_cities/world_cities.csv'

# Read Data File and store into Pandas Data Frames
city_data = pd.read_csv(world_cities)
# city_data = len(city_data)
city_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-efb594c22623> in <module>()
#       3
#       4 # Read Data File and store into Pandas Data Frames
# ----> 5 city_data = pd.read_csv(world_cities)
#       6 # city_data = len(city_data)
#       7 city_data
#
# ...

# %%
# Create a settings object with your API key and preferred units
# key = "AIzaSyAG6hNdWAkx2SUWhsaVCRJRq_pqEkS_UXA"

# Setting the units to imperial to get Fahrenheit reading
settings = {"units": "imperial", "appid": test.gkey}
test.gkey
# Out:
# 'AIzaSyAG6hNdWAkx2SUWhsaVCRJRq_pqEkS_UXA'

# %%
# # Import cities file as DataFrame
# cities_pd = pd.read_csv("../Resources/cities.csv")
# cities_pd

# %% [markdown]
# ## Generate a List of Cities

# %%
#  The Latitudes range from -90 to 90 and Longitudes range from -180 to 180
latitude = list(np.arange(-90,90.01,0.01))
longitude = list(np.arange(-180,180.01,0.01))

# %%
# # Ramdomly generate co-ordinates by setting Latitude and Longitude.
latitude_samples=random.sample(latitude,1000)
longitude_samples=random.sample(longitude,1000)
# latitude_samples

# %%
# # Setting Latitude and Longitude to ramdomly pick co-ordinates.
latitude_samples=random.sample(lat,1000)
longitude_samples=random.sample(long,1000)
# lat_samples

# %%
# # Creating a dataframe from the randomly sample Latitude and Longitude
cities_data = pd.DataFrame({"Latitude":latitude_samples,"Longitude":longitude_samples})

# %%
# # Randomly Creating a dataframe from the sample Latitude and Longitude
cities_data = pd.DataFrame({"Latitude":latitude_samples,"Longitude":longitude_samples})

# %%
# # New columns i.e. City and Country created for storing the corresponding details  of the co-ordinates.
cities_data["City"] = ""
cities_data["Country"] = ""
# cities_data

# %%
# # # Finding the city and the country code corresponding to the Latitude and Longitude
# for index,row in cities_data.iterrows():
#    #  city=citipy.nearest_city(row["Latitude"], row["Longitude"])
#     cities_data.set_value(index, "City", city.city_name)
#     cities_data.set_value(index, "Country", city.country_code)
    
# # Finding the city and the country code corresponding to the Latitude and Longitude
for index,row in cities_data.iterrows():
    city=citipy.nearest_city(row["Latitude"], row["Longitude"])
    cities_data.set_value(index, "City", city.city_name)
    cities_data.set_value(index, "Country", city.country_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-de3935ca6af3> in <module>()
#       7 # # Finding the city and the country code corresponding to the Latitude and Longitude
#       8 for index,row in cities_data.iterrows():
# ----> 9     city=citipy.nearest_city(row["Latitude"], row["Longitude"])
#      10     cities_data.set_value(index, "City", city.city_name)
#      11     cities_data.set_value(index, "Country", city.country_code)
#
# NameError: name 'citipy' is not defined

# %%
# # Dropping the Latitude and Longitude as they are values of the nearest city and not the excat co-ordinates of the city
# cities_DF=cities_DF.drop(cities_DF.columns[[0, 1]], axis=1)

# # Deleting duplicate values from the list of cities and keeping only the first
# cities_DF=cities_DF.drop_duplicates(['City'], keep='first')

# # Randomly sampling a list of 800 cities 
# cities_DF=cities_DF.sample(n=800)

# # Resetting the index of the cities list
# cities_DF=cities_DF.reset_index(drop=True)

# cities_DF.head()
# Out:
# [-180.0,
#  -179.99,
#  -179.98000000000002,
#  -179.97000000000003,
#  -179.96000000000004,
#  -179.95000000000005,
#  -179.94000000000005,
#  -179.93000000000006,
#  -179.92000000000007,
#  -179.91000000000008,
#  -179.9000000000001,
#  -179.8900000000001,
#  -179.8800000000001,
#  -179.87000000000012,
#  -179.86000000000013,
#  -179.85000000000014,
#  -179.84000000000015,
#  -179.83000000000015,
#  -179.82000000000016,
#  -179.81000000000017,
#  -179.80000000000018,
#  -179.7900000000002,
#  -179.7800000000002,
#  -179.7700000000002,
#  -179.76000000000022,
#  -179.75000000000023,
#  -179.74000000000024,
#  -179.73000000000025,
#  -179.72000000000025,
#  -179.71000000000026,
#  -179.70000000000027,
#  -179.69000000000028,
#  -179.6800000000003,
#  -179.6700000000003,
#  -179.6600000000003,
#  -179.65000000000032,
#  -179.64000000000033,
#  -179.63000000000034,
#  -179.62000000000035,
#  -179.61000000000035,
#  -179.60000000000036,
#  -179.59000000000037,
#  -179.58000000000038,
# ...

# %% [markdown]
# ## Perform API Calls

# %% [markdown]
# ## Latitude vs Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot
