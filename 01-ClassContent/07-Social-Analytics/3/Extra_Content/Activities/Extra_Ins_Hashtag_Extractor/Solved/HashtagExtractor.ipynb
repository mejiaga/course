# %%
# Dependencies
import numpy as np
import tweepy
import time
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Twitter API Keys
consumer_key = consumer_key
consumer_secret = consumer_secret
access_token = access_token
access_token_secret = access_token_secret

# %%
# Twitter Credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Term
target_term = "@RiversCuomo"

# %%
# Opening message
print("We're going live!")
# Out:
# We're going live!

# %%
# Search for most recent tweet directed to the account
public_tweets = api.search(target_term, count=1, result_type="recent")

# %%
# Extract all hashtags from tweets directed to the account
for tweet in public_tweets["statuses"]:

    # Print tweet in JSON
    print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))

    # Print tweet text
    print(tweet["text"])

    # Loop through all hashtags and print each one included
    for hashtag in tweet["entities"]["hashtags"]:
        print(hashtag["text"])
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Tue Mar 27 18:28:06 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 14327149,
#                 "id_str": "14327149",
#                 "indices": [
#                     3,
#                     15
#                 ],
#                 "name": "Rivers Cuomo",
#                 "screen_name": "RiversCuomo"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 978700202579300353,
#     "id_str": "978700202579300353",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "place": null,
#     "retweet_count": 49,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Tue Mar 27 16:51:22 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": []
#         },
#         "favorite_count": 371,
#         "favorited": false,
#         "geo": null,
#         "id": 978675859090440192,
#         "id_str": "978675859090440192",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "place": null,
#         "retweet_count": 49,
#         "retweeted": false,
#         "source": "<a href=\"https://panel.socialpilot.co/\" rel=\"nofollow\">SocialPilot.co</a>",
#         "text": "I want someone to look at me the way I look at Brian",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Mon Apr 07 21:31:51 +0000 2008",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "This is my fantasy channel. co-created w/the universe http://t.co/kN8fuQxGUC\nhttp://t.co/mKrN5oihPK snapchat: rivers.cuomo",
#             "entities": {
#                 "description": {
#                     "urls": [
#                         {
#                             "display_url": "facebook.com/riverscuomo",
#                             "expanded_url": "http://www.facebook.com/riverscuomo",
#                             "indices": [
#                                 54,
#                                 76
#                             ],
#                             "url": "http://t.co/kN8fuQxGUC"
#                         },
#                         {
#                             "display_url": "bit.ly/RC_Insta",
#                             "expanded_url": "http://bit.ly/RC_Insta",
#                             "indices": [
#                                 77,
#                                 99
#                             ],
#                             "url": "http://t.co/mKrN5oihPK"
#                         }
#                     ]
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "riverscuomo.com",
#                             "expanded_url": "http://www.riverscuomo.com",
#                             "indices": [
#                                 0,
#                                 22
#                             ],
#                             "url": "http://t.co/6ClYbPfpdh"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 3047,
#             "follow_request_sent": false,
#             "followers_count": 1268494,
#             "following": false,
#             "friends_count": 2235,
#             "geo_enabled": true,
#             "has_extended_profile": false,
#             "id": 14327149,
#             "id_str": "14327149",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 7068,
#             "location": "Los Angeles, CA",
#             "name": "Rivers Cuomo",
#             "notifications": false,
#             "profile_background_color": "0099B9",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/584880514978320384/rpzAyjho.jpg",
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/584880514978320384/rpzAyjho.jpg",
#             "profile_background_tile": true,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/14327149/1490120940",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/964617313910628353/qUbIdlOV_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/964617313910628353/qUbIdlOV_normal.jpg",
#             "profile_link_color": "0099B9",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "RiversCuomo",
#             "statuses_count": 3974,
#             "time_zone": "Pacific Time (US & Canada)",
#             "translator_type": "none",
#             "url": "http://t.co/6ClYbPfpdh",
#             "utc_offset": -25200,
#             "verified": true
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "text": "RT @RiversCuomo: I want someone to look at me the way I look at Brian",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Mon Mar 17 02:01:24 +0000 2014",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "I don't have much going for me | Rosales | operation Baywatch 2.0",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "youtube.com/user/ImpalaYT",
#                         "expanded_url": "https://www.youtube.com/user/ImpalaYT",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/eMw0axjQMl"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 3275,
#         "follow_request_sent": false,
#         "followers_count": 174,
#         "following": false,
#         "friends_count": 239,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 2393575520,
#         "id_str": "2393575520",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 2,
#         "location": "loser house",
#         "name": "Pat \ud83e\udd50",
#         "notifications": false,
#         "profile_background_color": "C0DEED",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/2393575520/1492776799",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/901294698974896128/-EhJlWUl_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/901294698974896128/-EhJlWUl_normal.jpg",
#         "profile_link_color": "050982",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "__Goodra__",
#         "statuses_count": 4250,
#         "time_zone": "Pacific Time (US & Canada)",
#         "translator_type": "none",
#         "url": "https://t.co/eMw0axjQMl",
#         "utc_offset": -25200,
#         "verified": false
#     }
# }
# RT @RiversCuomo: I want someone to look at me the way I look at Brian
