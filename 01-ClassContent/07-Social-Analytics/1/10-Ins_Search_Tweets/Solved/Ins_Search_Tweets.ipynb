# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Search Term
search_term = input("Which term would you like to search for? ")

# Search for all tweets
public_tweets = api.search(search_term)
public_tweets
# Out:
# Which term would you like to search for? dogs
# {'search_metadata': {'completed_in': 0.176,
#   'count': 15,
#   'max_id': 979000178144313345,
#   'max_id_str': '979000178144313345',
#   'next_results': '?max_id=979000157051092992&q=dogs&include_entities=1',
#   'query': 'dogs',
#   'refresh_url': '?since_id=979000178144313345&q=dogs&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 14:20:06 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/979000178144313345',
#       'indices': [117, 140],
#       'url': 'https://t.co/5wU1jhf67g'}],
#     'user_mentions': [{'id': 2892123022,
#       'id_str': '2892123022',
#       'indices': [20, 35],
#       'name': 'bowwowfilmfest',
#       'screen_name': 'bowwowfilmfest'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979000178144313345,
#    'id_str': '979000178144313345',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': 'Hot dogs! Today the @bowwowfilmfest comes to Waterville, Maine. Rejoice fans of film and furry four-legged friends,… https://t.co/5wU1jhf67g',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Feb 25 14:42:49 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Supporting and promoting arts and culture in historic Waterville - check out our online events calendar!',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'watervillecreates.org',
#         'expanded_url': 'http://watervillecreates.org',
#         'indices': [0, 22],
#         'url': 'http://t.co/OOedrJ40cI'}]}},
#     'favourites_count': 969,
#     'follow_request_sent': False,
#     'followers_count': 324,
#     'following': False,
#     'friends_count': 148,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 3062215870,
#     'id_str': '3062215870',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 19,
#     'location': 'Waterville, Maine, USA',
#     'name': 'Waterville Creates!',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3062215870/1472819247',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/598580533833146368/QHDB7cZL_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/598580533833146368/QHDB7cZL_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'WTVLCreates',
#     'statuses_count': 3919,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/OOedrJ40cI',
#     'utc_offset': -14400,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 14:20:05 +0000 2018',
#    'entities': {'hashtags': [{'indices': [25, 34], 'text': 'benefits'},
#      {'indices': [92, 106], 'text': 'PetsAreFamily'}],
#     'symbols': [],
#     'urls': [{'display_url': 'bit.ly/2G8LC2e',
#       'expanded_url': 'http://bit.ly/2G8LC2e',
#       'indices': [67, 90],
#       'url': 'https://t.co/xr379JJnCv'},
#      {'display_url': 'twitter.com/i/web/status/9…',
#       'expanded_url': 'https://twitter.com/i/web/status/979000177666220033',
#       'indices': [108, 131],
#       'url': 'https://t.co/pEZajfZgJE'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979000177666220033,
#    'id_str': '979000177666220033',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': 'Here check out 5 amazing #benefits of joint supplements for dogs 👉 https://t.co/xr379JJnCv  #PetsAreFamily… https://t.co/pEZajfZgJE',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri May 01 09:13:53 +0000 2015',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'A #beauty blogger, very well known to #natural skincare solutions, redefining the meaning of #skincare with natural #skincareproducts.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'revitol.us',
#         'expanded_url': 'http://www.revitol.us/',
#         'indices': [0, 22],
#         'url': 'http://t.co/Vd9y0snWmw'}]}},
#     'favourites_count': 108,
#     'follow_request_sent': False,
#     'followers_count': 116,
#     'following': False,
#     'friends_count': 195,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 3181527728,
#     'id_str': '3181527728',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 2,
#     'location': 'Pennsylvania, USA',
#     'name': 'Lisa J Fletcher',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3181527728/1431942000',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/594067544291446784/aEa076tB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/594067544291446784/aEa076tB_normal.jpg',
#     'profile_link_color': 'DD2E44',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'lisafletcher07',
#     'statuses_count': 142,
#     'time_zone': 'Chennai',
#     'translator_type': 'none',
#     'url': 'http://t.co/Vd9y0snWmw',
#     'utc_offset': 19800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 14:20:05 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'biggeekdad.com/2017/03/best-d…',
#       'expanded_url': 'https://biggeekdad.com/2017/03/best-dogs-cars/',
#       'indices': [0, 23],
#       'url': 'https://t.co/Lmh91KgvaJ'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979000176370208768,
#    'id_str': '979000176370208768',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'und',
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': 'https://t.co/Lmh91KgvaJ',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Nov 26 18:59:46 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "I like to share videos that I find funny, cool, and interesting. Who's Your Geek Daddy?",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'biggeekdad.com',
#         'expanded_url': 'https://biggeekdad.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/n3tbnb0Yn0'}]}},
#     'favourites_count': 70,
#     'follow_request_sent': False,
#     'followers_count': 452,
#     'following': False,
#     'friends_count': 11,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 17656608,
#     'id_str': '17656608',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 7,
#     'location': 'United States',
#     'name': 'Big Geek Daddy',
#     'notifications': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/9074739/Logo_Small.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/9074739/Logo_Small.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17656608/1517753570',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1157956682/BGD_normal.JPG',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1157956682/BGD_normal.JPG',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'BigGeekDaddy',
#     'statuses_count': 11437,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/n3tbnb0Yn0',
#     'utc_offset': -14400,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 14:20:05 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 255681332,
#       'id_str': '255681332',
#       'indices': [3, 16],
#       'name': 'Farmer Dixon',
#       'screen_name': 'SouthYeoEast'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979000175510237187,
#    'id_str': '979000175510237187',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 5,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 28 12:42:10 +0000 2018',
#     'entities': {'hashtags': [],
#      'media': [{'display_url': 'pic.twitter.com/QZuAVHYin0',
#        'expanded_url': 'https://twitter.com/SouthYeoEast/status/978975534045646851/photo/1',
#        'id': 978975530597978112,
#        'id_str': '978975530597978112',
#        'indices': [114, 137],
#        'media_url': 'http://pbs.twimg.com/media/DZYFDukXkAAEMCP.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/DZYFDukXkAAEMCP.jpg',
#        'sizes': {'large': {'h': 525, 'resize': 'fit', 'w': 1024},
#         'medium': {'h': 525, 'resize': 'fit', 'w': 1024},
#         'small': {'h': 349, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/QZuAVHYin0'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'display_url': 'pic.twitter.com/QZuAVHYin0',
#        'expanded_url': 'https://twitter.com/SouthYeoEast/status/978975534045646851/photo/1',
#        'id': 978975530597978112,
#        'id_str': '978975530597978112',
#        'indices': [114, 137],
#        'media_url': 'http://pbs.twimg.com/media/DZYFDukXkAAEMCP.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/DZYFDukXkAAEMCP.jpg',
#        'sizes': {'large': {'h': 525, 'resize': 'fit', 'w': 1024},
#         'medium': {'h': 525, 'resize': 'fit', 'w': 1024},
#         'small': {'h': 349, 'resize': 'fit', 'w': 680},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/QZuAVHYin0'}]},
#     'favorite_count': 28,
#     'favorited': False,
#     'geo': None,
#     'id': 978975534045646851,
#     'id_str': '978975534045646851',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 5,
#     'retweeted': False,
#     'source': '<a href="http://www.twitter.com" rel="nofollow">Twitter for Windows Phone</a>',
#     'text': 'The dogs enjoying a brief moment of sun between the showers (while waiting for their favourite postman to arrive) https://t.co/QZuAVHYin0',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Feb 21 21:14:09 +0000 2011',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': "We're Ian & Gillian Dixon, working a traditional mixed farm in Devon; we rear native breeds of sheep, cattle, pigs & poultry & run intro courses 4 smallholders",
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'southyeofarm.co.uk',
#          'expanded_url': 'http://www.southyeofarm.co.uk',
#          'indices': [0, 23],
#          'url': 'https://t.co/HZ4lGcXN2C'}]}},
#      'favourites_count': 9441,
#      'follow_request_sent': False,
#      'followers_count': 5436,
#      'following': False,
#      'friends_count': 3376,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 255681332,
#      'id_str': '255681332',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 138,
#      'location': 'Northlew, Devon, GB',
#      'name': 'Farmer Dixon',
#      'notifications': False,
#      'profile_background_color': '8D9FA8',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/354242491/Twitter_background6.jpg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/354242491/Twitter_background6.jpg',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/255681332/1496773578',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/675738411777531904/xpGSmCmI_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/675738411777531904/xpGSmCmI_normal.jpg',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': '8A753E',
#      'profile_sidebar_fill_color': '8AACBF',
#      'profile_text_color': '755F33',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'SouthYeoEast',
#      'statuses_count': 20280,
#      'time_zone': 'London',
#      'translator_type': 'none',
#      'url': 'https://t.co/HZ4lGcXN2C',
#      'utc_offset': 3600,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @SouthYeoEast: The dogs enjoying a brief moment of sun between the showers (while waiting for their favourite postman to arrive) https:/…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Feb 03 06:07:50 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Curator of life and living along the Salish Sea... unceded Lekwungen (Songhees & Esquimalt) First Nations territory.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 35029,
#     'follow_request_sent': False,
#     'followers_count': 328,
#     'following': False,
#     'friends_count': 231,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 246657960,
#     'id_str': '246657960',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 64,
#     'location': 'Victoria, British Columbia',
#     'name': 'GreatWhiteN212',
#     'notifications': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/246657960/1512004526',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/936040195056484352/jnf1SCLX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/936040195056484352/jnf1SCLX_normal.jpg',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ksbrooker',
#     'statuses_count': 44615,
#     'time_zone': 'Mountain Time (US & Canada)',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -21600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 14:20:04 +0000 2018',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/PJOrrftBqi',
#       'expanded_url': 'https://twitter.com/zboah/status/978998198768463872/video/1',
#       'id': 978998152765177857,
#       'id_str': '978998152765177857',
#       'indices': [50, 73],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 576},
#        'medium': {'h': 720, 'resize': 'fit', 'w': 576},
#        'small': {'h': 680, 'resize': 'fit', 'w': 544},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 978998198768463872,
#       'source_status_id_str': '978998198768463872',
#       'source_user_id': 3439105463,
#       'source_user_id_str': '3439105463',
#       'type': 'photo',
#       'url': 'https://t.co/PJOrrftBqi'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3439105463,
#       'id_str': '3439105463',
#       'indices': [3, 9],
#       'name': '🐕',
#       'screen_name': 'zboah'}]},
#    'extended_entities': {'media': [{'additional_media_info': {'monetizable': False,
#        'source_user': {'contributors_enabled': False,
#         'created_at': 'Tue Aug 25 12:43:14 +0000 2015',
#         'default_profile': True,
#         'default_profile_image': False,
#         'description': '•sharing the cutest animal content on twitter! • all credit found on posts• dm for removal!•',
#         'entities': {'description': {'urls': []},
#          'url': {'urls': [{'display_url': 'zboah.com',
#             'expanded_url': 'http://zboah.com',
#             'indices': [0, 23],
#             'url': 'https://t.co/JGTlVvxTUx'}]}},
#         'favourites_count': 8051,
#         'follow_request_sent': False,
#         'followers_count': 299275,
#         'following': False,
#         'friends_count': 15,
#         'geo_enabled': True,
#         'has_extended_profile': False,
#         'id': 3439105463,
#         'id_str': '3439105463',
#         'is_translation_enabled': False,
#         'is_translator': False,
#         'lang': 'en',
#         'listed_count': 3136,
#         'location': 'I own no content posted',
#         'name': '🐕',
#         'notifications': False,
#         'profile_background_color': 'C0DEED',
#         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#         'profile_background_tile': False,
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3439105463/1522107634',
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/978456631108186114/0EsZy-xJ_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978456631108186114/0EsZy-xJ_normal.jpg',
#         'profile_link_color': '1DA1F2',
#         'profile_sidebar_border_color': 'C0DEED',
#         'profile_sidebar_fill_color': 'DDEEF6',
#         'profile_text_color': '333333',
#         'profile_use_background_image': True,
#         'protected': False,
#         'screen_name': 'zboah',
#         'statuses_count': 69789,
#         'time_zone': 'Pacific Time (US & Canada)',
#         'translator_type': 'none',
#         'url': 'https://t.co/JGTlVvxTUx',
#         'utc_offset': -25200,
#         'verified': False}},
#       'display_url': 'pic.twitter.com/PJOrrftBqi',
#       'expanded_url': 'https://twitter.com/zboah/status/978998198768463872/video/1',
#       'id': 978998152765177857,
#       'id_str': '978998152765177857',
#       'indices': [50, 73],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 576},
#        'medium': {'h': 720, 'resize': 'fit', 'w': 576},
#        'small': {'h': 680, 'resize': 'fit', 'w': 544},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 978998198768463872,
#       'source_status_id_str': '978998198768463872',
#       'source_user_id': 3439105463,
#       'source_user_id_str': '3439105463',
#       'type': 'video',
#       'url': 'https://t.co/PJOrrftBqi',
#       'video_info': {'aspect_ratio': [4, 5],
#        'duration_millis': 14067,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/vid/512x640/FZHL3S_lPBPTj463.mp4'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/pl/sWqewwvO7jqvMy_x.m3u8'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/vid/256x320/I-c6et7afoGc0ZYz.mp4'}]}}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979000172758818816,
#    'id_str': '979000172758818816',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 200,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 28 14:12:14 +0000 2018',
#     'entities': {'hashtags': [],
#      'media': [{'display_url': 'pic.twitter.com/PJOrrftBqi',
#        'expanded_url': 'https://twitter.com/zboah/status/978998198768463872/video/1',
#        'id': 978998152765177857,
#        'id_str': '978998152765177857',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#        'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 576},
#         'medium': {'h': 720, 'resize': 'fit', 'w': 576},
#         'small': {'h': 680, 'resize': 'fit', 'w': 544},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/PJOrrftBqi'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#        'display_url': 'pic.twitter.com/PJOrrftBqi',
#        'expanded_url': 'https://twitter.com/zboah/status/978998198768463872/video/1',
#        'id': 978998152765177857,
#        'id_str': '978998152765177857',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#        'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 576},
#         'medium': {'h': 720, 'resize': 'fit', 'w': 576},
#         'small': {'h': 680, 'resize': 'fit', 'w': 544},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'video',
#        'url': 'https://t.co/PJOrrftBqi',
#        'video_info': {'aspect_ratio': [4, 5],
#         'duration_millis': 14067,
#         'variants': [{'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/vid/512x640/FZHL3S_lPBPTj463.mp4'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/pl/sWqewwvO7jqvMy_x.m3u8'},
#          {'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/vid/256x320/I-c6et7afoGc0ZYz.mp4'}]}}]},
#     'favorite_count': 427,
#     'favorited': False,
#     'geo': None,
#     'id': 978998198768463872,
#     'id_str': '978998198768463872',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': True,
#     'retweet_count': 200,
#     'retweeted': False,
#     'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#     'text': 'The final stick boss \n\n📹IG: lnsta_dogs https://t.co/PJOrrftBqi',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Aug 25 12:43:14 +0000 2015',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '•sharing the cutest animal content on twitter! • all credit found on posts• dm for removal!•',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'zboah.com',
#          'expanded_url': 'http://zboah.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/JGTlVvxTUx'}]}},
#      'favourites_count': 8051,
#      'follow_request_sent': False,
#      'followers_count': 299275,
#      'following': False,
#      'friends_count': 15,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 3439105463,
#      'id_str': '3439105463',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 3136,
#      'location': 'I own no content posted',
#      'name': '🐕',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3439105463/1522107634',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/978456631108186114/0EsZy-xJ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978456631108186114/0EsZy-xJ_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'zboah',
#      'statuses_count': 69789,
#      'time_zone': 'Pacific Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'https://t.co/JGTlVvxTUx',
#      'utc_offset': -25200,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @zboah: The final stick boss \n\n📹IG: lnsta_dogs https://t.co/PJOrrftBqi',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jan 13 08:52:26 +0000 2018',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '그림계정 @mare_loves_you 마레 혹은 야진으로 불러주세요 동물 사랑함 인간은 제외하고요 인간 죽었으면 다 불살랐으면',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 2307,
#     'follow_request_sent': False,
#     'followers_count': 260,
#     'following': False,
#     'friends_count': 197,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 952101018346520577,
#     'id_str': '952101018346520577',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'ko',
#     'listed_count': 1,
#     'location': '흑발공 주시오',
#     'name': '돈조금받으면살인하는사람',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/952101018346520577/1516693070',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/978319906591539201/cr-py-bS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978319906591539201/cr-py-bS_normal.jpg',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'yespainnogain',
#     'statuses_count': 10129,
#     'time_zone': 'Seoul',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 32400,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 14:20:04 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 726237017483276289,
#       'id_str': '726237017483276289',
#       'indices': [3, 16],
#       'name': 'sarah',
#       'screen_name': 'jintoxicated'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979000172574158848,
#    'id_str': '979000172574158848',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 2661,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Tue Mar 27 00:46:49 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/978433123678502912',
#        'indices': [117, 140],
#        'url': 'https://t.co/ksmzApo6eG'}],
#      'user_mentions': []},
#     'favorite_count': 5645,
#     'favorited': False,
#     'geo': None,
#     'id': 978433123678502912,
#     'id_str': '978433123678502912',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 2661,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "whoever is directing run should be reigned as the nation's hero, we got to see bts in concepts we only read in fanf… https://t.co/ksmzApo6eG",
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Apr 30 02:29:32 +0000 2016',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'you are the sun, the moon, the stars and all that other good shit #BTSLoveMyself #ENDviolence',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'curiouscat.me/jintoxicated',
#          'expanded_url': 'http://curiouscat.me/jintoxicated',
#          'indices': [0, 23],
#          'url': 'https://t.co/arY0kSALIi'}]}},
#      'favourites_count': 51455,
#      'follow_request_sent': False,
#      'followers_count': 49653,
#      'following': False,
#      'friends_count': 1159,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 726237017483276289,
#      'id_str': '726237017483276289',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 544,
#      'location': '',
#      'name': 'sarah',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/726237017483276289/1520246123',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/970608705262596096/_1oi6QDX_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/970608705262596096/_1oi6QDX_normal.jpg',
#      'profile_link_color': 'F58EA8',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'jintoxicated',
#      'statuses_count': 61074,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/arY0kSALIi',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': "RT @jintoxicated: whoever is directing run should be reigned as the nation's hero, we got to see bts in concepts we only read in fanfics. y…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Nov 15 04:56:29 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'ARMY | OT7🌈 | Vkook 👬🤳💕 • Namjin • Yoonmin | Hoseok is my Sun ☀️',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 25171,
#     'follow_request_sent': False,
#     'followers_count': 66,
#     'following': False,
#     'friends_count': 38,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 930660754000359424,
#     'id_str': '930660754000359424',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 4,
#     'location': 'Republic of Korea',
#     'name': 'Chul',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/930660754000359424/1520120340',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/972231845453512704/1cfRXt-A_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/972231845453512704/1cfRXt-A_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'se_chul',
#     'statuses_count': 6753,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 14:20:03 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 834899546161430528,
#       'id_str': '834899546161430528',
#       'indices': [3, 11],
#       'name': '🏆James Douglass🏆',
#       'screen_name': 'jamdugg'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979000167524438016,
#    'id_str': '979000167524438016',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 214,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Feb 14 02:34:16 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'favorite_count': 542,
#     'favorited': False,
#     'geo': None,
#     'id': 963602259706896385,
#     'id_str': '963602259706896385',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 214,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': 'Confusing Math:\n\nDogs = Awesome\nChocolate = Awesome\nDogs + Chocolate = Not Awesome',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Feb 23 22:55:38 +0000 2017',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '⬆️ ...This guy...',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'favstar.fm/users/jamdugg',
#          'expanded_url': 'https://favstar.fm/users/jamdugg',
#          'indices': [0, 23],
#          'url': 'https://t.co/Yckpo5j9sV'}]}},
#      'favourites_count': 8594,
#      'follow_request_sent': False,
#      'followers_count': 1853,
#      'following': False,
#      'friends_count': 1155,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 834899546161430528,
#      'id_str': '834899546161430528',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 25,
#      'location': 'Newk Yor City/Seattle',
#      'name': '🏆James Douglass🏆',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/834899546161430528/1516401537',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/975409615440633858/IsKrdwW6_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/975409615440633858/IsKrdwW6_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'jamdugg',
#      'statuses_count': 3010,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/Yckpo5j9sV',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @jamdugg: Confusing Math:\n\nDogs = Awesome\nChocolate = Awesome\nDogs + Chocolate = Not Awesome',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jun 04 21:43:52 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Spartan, Jedi, Master Assassin, Part Time Ninja, & a whole lot of deliciousness all rolled into one.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'favstar.fm/users/ThaiCali…',
#         'expanded_url': 'http://favstar.fm/users/ThaiCaliber',
#         'indices': [0, 23],
#         'url': 'https://t.co/DGACJbt7Mu'}]}},
#     'favourites_count': 69101,
#     'follow_request_sent': False,
#     'followers_count': 1990,
#     'following': False,
#     'friends_count': 1751,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 152021542,
#     'id_str': '152021542',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 60,
#     'location': 'Lost Inside Avengers Tower',
#     'name': 'Richie Not So Rich',
#     'notifications': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/537239948978438144/eznbVbTK.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/537239948978438144/eznbVbTK.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/152021542/1368580091',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/943902024680329216/f_dr6DIp_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/943902024680329216/f_dr6DIp_normal.jpg',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ThaiCaliber',
#     'statuses_count': 166685,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/DGACJbt7Mu',
#     'utc_offset': -14400,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 14:20:03 +0000 2018',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 209088798,
#       'id_str': '209088798',
#       'indices': [3, 13],
#       'name': 'Penny',
#       'screen_name': 'Penny2449'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979000166991777792,
#    'id_str': '979000166991777792',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 28 14:18:15 +0000 2018',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#        'expanded_url': 'https://twitter.com/i/web/status/978999714216636416',
#        'indices': [117, 140],
#        'url': 'https://t.co/POVBqbUhHp'}],
#      'user_mentions': []},
#     'favorite_count': 0,
#     'favorited': False,
#     'geo': None,
#     'id': 978999714216636416,
#     'id_str': '978999714216636416',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'text': 'Kent - Duke 7 yr old male Lurcher cross, Duke is a very sweet boy who seems a little lost in kennels at the moment.… https://t.co/POVBqbUhHp',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Oct 28 13:56:31 +0000 2010',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'married, love my staffie, mad on motogp bsb wsb,  I tweet a lot of dogs needing homes, you have been warned !',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 7415,
#      'follow_request_sent': False,
#      'followers_count': 4419,
#      'following': False,
#      'friends_count': 2023,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 209088798,
#      'id_str': '209088798',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 87,
#      'location': 'England',
#      'name': 'Penny',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/209088798/1362002522',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/974021384644030465/GPzaxW16_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/974021384644030465/GPzaxW16_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'Penny2449',
#      'statuses_count': 127294,
#      'time_zone': 'London',
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': 3600,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @Penny2449: Kent - Duke 7 yr old male Lurcher cross, Duke is a very sweet boy who seems a little lost in kennels at the moment. He is go…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri May 18 13:03:34 +0000 2012',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'tweet to try to help dogs in rescue furever homes #TeamFFH , volunteer with SSPCA 🐶🐶',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 79287,
#     'follow_request_sent': False,
#     'followers_count': 2925,
#     'following': False,
#     'friends_count': 1388,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 583791139,
#     'id_str': '583791139',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 328,
#     'location': '',
#     'name': 'karen',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/583791139/1519561439',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/960854136702021632/Gi50aGyw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/960854136702021632/Gi50aGyw_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'karen73984451',
#     'statuses_count': 275404,
#     'time_zone': None,
# ...
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 16,
#      'location': '',
#      'name': 'Ellen Jackson',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1210091365/1508859089',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/922847941290872834/hHje5ffU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/922847941290872834/hHje5ffU_normal.jpg',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'Eljackson25',
#      'statuses_count': 12573,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/BlEPP5dzxS',
#      'utc_offset': None,
#      'verified': False}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': "RT @Eljackson25: Your dog would look great in a sweater in your favorite team's colors. Custom order dog sweaters are only $15! Order today…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Oct 06 16:23:57 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Interior and Architectural Designer.\nThe Rustic Pelican is proud to offer amazing #Rustic #farmhouse #Modern #Handmade #designs for your home or office.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'therusticpelican.com',
#         'expanded_url': 'https://www.therusticpelican.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/y0V365Zg2w'}]}},
#     'favourites_count': 60692,
#     'follow_request_sent': False,
#     'followers_count': 7236,
#     'following': False,
#     'friends_count': 6711,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 784066673141612544,
#     'id_str': '784066673141612544',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 176,
#     'location': 'Florida, USA',
#     'name': 'The Rustic Pelican',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/784066673141612544/1475876977',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/784510589678727168/3GwXGdJp_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/784510589678727168/3GwXGdJp_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'RusticPelican',
#     'statuses_count': 57835,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/y0V365Zg2w',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 28 14:20:01 +0000 2018',
#    'entities': {'hashtags': [],
#     'media': [{'display_url': 'pic.twitter.com/PJOrrftBqi',
#       'expanded_url': 'https://twitter.com/zboah/status/978998198768463872/video/1',
#       'id': 978998152765177857,
#       'id_str': '978998152765177857',
#       'indices': [50, 73],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 576},
#        'medium': {'h': 720, 'resize': 'fit', 'w': 576},
#        'small': {'h': 680, 'resize': 'fit', 'w': 544},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 978998198768463872,
#       'source_status_id_str': '978998198768463872',
#       'source_user_id': 3439105463,
#       'source_user_id_str': '3439105463',
#       'type': 'photo',
#       'url': 'https://t.co/PJOrrftBqi'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 3439105463,
#       'id_str': '3439105463',
#       'indices': [3, 9],
#       'name': '🐕',
#       'screen_name': 'zboah'}]},
#    'extended_entities': {'media': [{'additional_media_info': {'monetizable': False,
#        'source_user': {'contributors_enabled': False,
#         'created_at': 'Tue Aug 25 12:43:14 +0000 2015',
#         'default_profile': True,
#         'default_profile_image': False,
#         'description': '•sharing the cutest animal content on twitter! • all credit found on posts• dm for removal!•',
#         'entities': {'description': {'urls': []},
#          'url': {'urls': [{'display_url': 'zboah.com',
#             'expanded_url': 'http://zboah.com',
#             'indices': [0, 23],
#             'url': 'https://t.co/JGTlVvxTUx'}]}},
#         'favourites_count': 8051,
#         'follow_request_sent': False,
#         'followers_count': 299275,
#         'following': False,
#         'friends_count': 15,
#         'geo_enabled': True,
#         'has_extended_profile': False,
#         'id': 3439105463,
#         'id_str': '3439105463',
#         'is_translation_enabled': False,
#         'is_translator': False,
#         'lang': 'en',
#         'listed_count': 3136,
#         'location': 'I own no content posted',
#         'name': '🐕',
#         'notifications': False,
#         'profile_background_color': 'C0DEED',
#         'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#         'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#         'profile_background_tile': False,
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3439105463/1522107634',
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/978456631108186114/0EsZy-xJ_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978456631108186114/0EsZy-xJ_normal.jpg',
#         'profile_link_color': '1DA1F2',
#         'profile_sidebar_border_color': 'C0DEED',
#         'profile_sidebar_fill_color': 'DDEEF6',
#         'profile_text_color': '333333',
#         'profile_use_background_image': True,
#         'protected': False,
#         'screen_name': 'zboah',
#         'statuses_count': 69789,
#         'time_zone': 'Pacific Time (US & Canada)',
#         'translator_type': 'none',
#         'url': 'https://t.co/JGTlVvxTUx',
#         'utc_offset': -25200,
#         'verified': False}},
#       'display_url': 'pic.twitter.com/PJOrrftBqi',
#       'expanded_url': 'https://twitter.com/zboah/status/978998198768463872/video/1',
#       'id': 978998152765177857,
#       'id_str': '978998152765177857',
#       'indices': [50, 73],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 576},
#        'medium': {'h': 720, 'resize': 'fit', 'w': 576},
#        'small': {'h': 680, 'resize': 'fit', 'w': 544},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 978998198768463872,
#       'source_status_id_str': '978998198768463872',
#       'source_user_id': 3439105463,
#       'source_user_id_str': '3439105463',
#       'type': 'video',
#       'url': 'https://t.co/PJOrrftBqi',
#       'video_info': {'aspect_ratio': [4, 5],
#        'duration_millis': 14067,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/vid/512x640/FZHL3S_lPBPTj463.mp4'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/pl/sWqewwvO7jqvMy_x.m3u8'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/vid/256x320/I-c6et7afoGc0ZYz.mp4'}]}}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 979000157051092993,
#    'id_str': '979000157051092993',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 200,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Wed Mar 28 14:12:14 +0000 2018',
#     'entities': {'hashtags': [],
#      'media': [{'display_url': 'pic.twitter.com/PJOrrftBqi',
#        'expanded_url': 'https://twitter.com/zboah/status/978998198768463872/video/1',
#        'id': 978998152765177857,
#        'id_str': '978998152765177857',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#        'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 576},
#         'medium': {'h': 720, 'resize': 'fit', 'w': 576},
#         'small': {'h': 680, 'resize': 'fit', 'w': 544},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/PJOrrftBqi'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#        'display_url': 'pic.twitter.com/PJOrrftBqi',
#        'expanded_url': 'https://twitter.com/zboah/status/978998198768463872/video/1',
#        'id': 978998152765177857,
#        'id_str': '978998152765177857',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/978998152765177857/pu/img/8Dh9EijJWQltdip5.jpg',
#        'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 576},
#         'medium': {'h': 720, 'resize': 'fit', 'w': 576},
#         'small': {'h': 680, 'resize': 'fit', 'w': 544},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'video',
#        'url': 'https://t.co/PJOrrftBqi',
#        'video_info': {'aspect_ratio': [4, 5],
#         'duration_millis': 14067,
#         'variants': [{'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/vid/512x640/FZHL3S_lPBPTj463.mp4'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/pl/sWqewwvO7jqvMy_x.m3u8'},
#          {'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/978998152765177857/pu/vid/256x320/I-c6et7afoGc0ZYz.mp4'}]}}]},
#     'favorite_count': 427,
#     'favorited': False,
#     'geo': None,
#     'id': 978998198768463872,
#     'id_str': '978998198768463872',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': True,
#     'retweet_count': 200,
#     'retweeted': False,
#     'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#     'text': 'The final stick boss \n\n📹IG: lnsta_dogs https://t.co/PJOrrftBqi',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Aug 25 12:43:14 +0000 2015',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '•sharing the cutest animal content on twitter! • all credit found on posts• dm for removal!•',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'zboah.com',
#          'expanded_url': 'http://zboah.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/JGTlVvxTUx'}]}},
#      'favourites_count': 8051,
#      'follow_request_sent': False,
#      'followers_count': 299275,
#      'following': False,
#      'friends_count': 15,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 3439105463,
#      'id_str': '3439105463',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'en',
#      'listed_count': 3136,
#      'location': 'I own no content posted',
#      'name': '🐕',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3439105463/1522107634',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/978456631108186114/0EsZy-xJ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978456631108186114/0EsZy-xJ_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'zboah',
#      'statuses_count': 69789,
#      'time_zone': 'Pacific Time (US & Canada)',
#      'translator_type': 'none',
#      'url': 'https://t.co/JGTlVvxTUx',
#      'utc_offset': -25200,
#      'verified': False}},
#    'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>',
#    'text': 'RT @zboah: The final stick boss \n\n📹IG: lnsta_dogs https://t.co/PJOrrftBqi',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Sep 01 21:54:59 +0000 2013',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 5921,
#     'follow_request_sent': False,
#     'followers_count': 8,
#     'following': False,
#     'friends_count': 92,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1720363711,
#     'id_str': '1720363711',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'th',
#     'listed_count': 1,
#     'location': '',
#     'name': '🎬✨',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1720363711/1520066087',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/969853540360335360/zs6upVVJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/969853540360335360/zs6upVVJ_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'lliinn_92',
#     'statuses_count': 3429,
#     'time_zone': 'Jakarta',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 25200,
#     'verified': False}}]}

# %%
# View Search Object
# print(public_tweets)

# Loop through all tweets
for tweet in public_tweets["statuses"]:

    # Utilize JSON dumps to generate a pretty-printed json
    # print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
    print(tweet["text"])
# Out:
# Hot dogs! Today the @bowwowfilmfest comes to Waterville, Maine. Rejoice fans of film and furry four-legged friends,… https://t.co/5wU1jhf67g
# Here check out 5 amazing #benefits of joint supplements for dogs 👉 https://t.co/xr379JJnCv  #PetsAreFamily… https://t.co/pEZajfZgJE
# https://t.co/Lmh91KgvaJ
# RT @SouthYeoEast: The dogs enjoying a brief moment of sun between the showers (while waiting for their favourite postman to arrive) https:/…
# RT @zboah: The final stick boss
#
# 📹IG: lnsta_dogs https://t.co/PJOrrftBqi
# RT @jintoxicated: whoever is directing run should be reigned as the nation's hero, we got to see bts in concepts we only read in fanfics. y…
# RT @jamdugg: Confusing Math:
#
# Dogs = Awesome
# Chocolate = Awesome
# Dogs + Chocolate = Not Awesome
# RT @Penny2449: Kent - Duke 7 yr old male Lurcher cross, Duke is a very sweet boy who seems a little lost in kennels at the moment. He is go…
# RT @ehjovan: do dogs all speak the same language or do they have regional dialects https://t.co/fYyg7TG27E
# RT @ehjovan: do dogs all speak the same language or do they have regional dialects https://t.co/fYyg7TG27E
# RT @zboah: The final stick boss
#
# 📹IG: lnsta_dogs https://t.co/PJOrrftBqi
# RT @USAMilitaryUSA: RIP WAR DOGS https://t.co/i5ZLnRyZSw
# RT @ehjovan: do dogs all speak the same language or do they have regional dialects https://t.co/fYyg7TG27E
# RT @Eljackson25: Your dog would look great in a sweater in your favorite team's colors. Custom order dog sweaters are only $15! Order today…
# RT @zboah: The final stick boss
#
# 📹IG: lnsta_dogs https://t.co/PJOrrftBqi
